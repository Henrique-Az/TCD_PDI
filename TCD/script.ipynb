# %% [markdown]
# ## Reconhecimento de digitais

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt


imagem=cv2.imread("imagens/012_3_1.tif", cv2.IMREAD_GRAYSCALE)
plt.imshow(imagem, cmap='gray', vmin=0, vmax=255)
